# %% [markdown]
# <a href="https://colab.research.google.com/github/fransis1245/Repos/blob/main/Ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Ejercicios de Python
#
# -------------------------------------

# %% [markdown]
# Tarea
